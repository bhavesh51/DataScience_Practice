# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.chdir)
os.getcwd()
# Out:
# <built-in function chdir>
# 'c:\\Users\\bhave\\Desktop\\code\\DataScience_Practice'

# %%
ls
# Out:
# Volume in drive C has no label.
#  Volume Serial Number is 84A3-6A1D
#
#  Directory of c:\Users\bhave\Desktop\code\DataScience_Practice
#
# 17-Jul-20  07:21 AM    <DIR>          .
# 17-Jul-20  07:21 AM    <DIR>          ..
# 10-Jul-20  12:35 AM    <DIR>          .ipynb_checkpoints
# 17-Jul-20  07:21 AM                23 .jovianrc
# 10-Jul-20  12:36 AM               800 best_practice.ipynb
# 12-Jul-20  09:18 PM    <DIR>          Dataset
# 17-Jul-20  07:37 AM               868 Iris_classification.R
# 10-Jul-20  12:25 AM           270,801 Novaritis.ipynb
# 10-Jul-20  12:25 AM             7,342 Python_EDA.ipynb
#                5 File(s)        279,834 bytes
#                4 Dir(s)  10,783,813,632 bytes free

# %%
ls Dataset/
# Out:
# sample_submission.csv  Test.csv  Train.csv

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
train_data = pd.read_csv('Dataset/Train.csv')

# %%
train_data.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   174   1.0    92    29    36                 0
# 1   236   1.0   103   142    34                 1
# 2   174   1.0   110    93    34                 1
# 3   249   1.0    72    29    34                 1
# 4   174   0.0   112    29    43                 1

# %%
train_data.columns
# Out:
# Index(['INCIDENT_ID', 'DATE', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 'X_7',
#        'X_8', 'X_9', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15',
#        'MULTIPLE_OFFENSE'],
#       dtype='object')

# %%
test_data = pd.read_csv('Dataset/Test.csv')

# %%
test_data.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# 1   CR_103520  05-MAR-04    0   44   44    1    3    7    1    4    6     1
# 2   CR_196089  27-JAN-18    0   34   33    3    5    2    7    3    0     1
# 3   CR_112195  18-AUG-06    7    3    2    3    5    9    8    0    5     1
# 4   CR_149832  31-OCT-11    0    7    8    7    3    2    7    1    5     1
#
#    X_11  X_12  X_13  X_14  X_15
# 0   174   NaN    72   119    23
# 1   316   0.0    12    29    34
# 2   316   1.0    72     0    34
# 3   174   1.0   112    87    34
# 4   174   0.0   112    93    43

# %%
test_data.columns
# Out:
# Index(['INCIDENT_ID', 'DATE', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 'X_7',
#        'X_8', 'X_9', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15'],
#       dtype='object')

# %%
train_data.describe()
# Out:
#                 X_1           X_2           X_3           X_4           X_5  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       0.483778     24.791206     24.637450      4.276744      2.455609
# std        1.439738     15.240231     15.135093      2.944672      1.963095
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      7.000000      8.000000      2.000000      1.000000
# 50%        0.000000     24.000000     24.000000      4.000000      3.000000
# 75%        0.000000     36.000000     35.000000      6.000000      5.000000
# max        7.000000     52.000000     52.000000     10.000000      5.000000
#
#                 X_6           X_7           X_8           X_9          X_10  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       6.154175      4.876509      0.972460      4.924128      1.244802
# ...

# %%
train_data.isnull().sum()
# Out:
# INCIDENT_ID           0
# DATE                  0
# X_1                   0
# X_2                   0
# X_3                   0
# X_4                   0
# X_5                   0
# X_6                   0
# X_7                   0
# X_8                   0
# X_9                   0
# X_10                  0
# X_11                  0
# X_12                182
# X_13                  0
# X_14                  0
# X_15                  0
# MULTIPLE_OFFENSE      0
# dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INCIDENT_ID       23856 non-null  object
#  1   DATE              23856 non-null  object
#  2   X_1               23856 non-null  int64
#  3   X_2               23856 non-null  int64
#  4   X_3               23856 non-null  int64
#  5   X_4               23856 non-null  int64
#  6   X_5               23856 non-null  int64
#  7   X_6               23856 non-null  int64
#  8   X_7               23856 non-null  int64
#  9   X_8               23856 non-null  int64
#  10  X_9               23856 non-null  int64
#  11  X_10              23856 non-null  int64
#  12  X_11              23856 non-null  int64
#  13  X_12              23674 non-null  float64
#  14  X_13              23856 non-null  int64
#  15  X_14              23856 non-null  int64
# ...

# %%
train_data.shape
# Out:
# (23856, 18)

# %%
test_data.shape
# Out:
# (15903, 17)

# %%
def miss_data(df):
    x = ['column_name','missing_data', 'missing_in_percentage']
    missing_data = pd.DataFrame(columns=x)
    columns = df.columns
    for col in columns:
        icolumn_name = col
        imissing_data = df[col].isnull().sum()
        imissing_in_percentage = (df[col].isnull().sum()/df[col].shape[0])*100

        missing_data.loc[len(missing_data)] = [icolumn_name, imissing_data, imissing_in_percentage]
    print(missing_data)

# %%
miss_data(train_data)
# Out:
#          column_name missing_data  missing_in_percentage
# 0        INCIDENT_ID            0               0.000000
# 1               DATE            0               0.000000
# 2                X_1            0               0.000000
# 3                X_2            0               0.000000
# 4                X_3            0               0.000000
# 5                X_4            0               0.000000
# 6                X_5            0               0.000000
# 7                X_6            0               0.000000
# 8                X_7            0               0.000000
# 9                X_8            0               0.000000
# 10               X_9            0               0.000000
# 11              X_10            0               0.000000
# 12              X_11            0               0.000000
# 13              X_12          182               0.762911
# 14              X_13            0               0.000000
# ...

# %%
miss_data(test_data)
# Out:
#     column_name missing_data  missing_in_percentage
# 0   INCIDENT_ID            0               0.000000
# 1          DATE            0               0.000000
# 2           X_1            0               0.000000
# 3           X_2            0               0.000000
# 4           X_3            0               0.000000
# 5           X_4            0               0.000000
# 6           X_5            0               0.000000
# 7           X_6            0               0.000000
# 8           X_7            0               0.000000
# 9           X_8            0               0.000000
# 10          X_9            0               0.000000
# 11         X_10            0               0.000000
# 12         X_11            0               0.000000
# 13         X_12          127               0.798591
# 14         X_13            0               0.000000
# 15         X_14            0               0.000000
# 16         X_15            0               0.000000

# %%
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
#         mz_table.to_excel('D:/sampledata/missing_and_zero_values.xlsx', freeze_panes=(1,0), index = False)
        return mz_table

missing_zero_values_table(train_data)
# Out:
# Your selected dataframe has 18 columns and 23856 Rows.
# There are 1 columns that have missing values.
#       Zero Values  Missing Values  % of Total Values  \
# X_12         5171             182                0.8
#
#       Total Zero Missing Values  % Total Zero Missing Values Data Type
# X_12                       5353                         22.4   float64

# %%
train_data.fillna(train_data.mean(), inplace=True)

# %%
missing_zero_values_table(train_data)
# Out:
# Your selected dataframe has 18 columns and 23856 Rows.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Zero Values, Missing Values, % of Total Values, Total Zero Missing Values, % Total Zero Missing Values, Data Type]
# Index: []

# %%
miss_data(train_data)
# Out:
#          column_name missing_data  missing_in_percentage
# 0        INCIDENT_ID            0                    0.0
# 1               DATE            0                    0.0
# 2                X_1            0                    0.0
# 3                X_2            0                    0.0
# 4                X_3            0                    0.0
# 5                X_4            0                    0.0
# 6                X_5            0                    0.0
# 7                X_6            0                    0.0
# 8                X_7            0                    0.0
# 9                X_8            0                    0.0
# 10               X_9            0                    0.0
# 11              X_10            0                    0.0
# 12              X_11            0                    0.0
# 13              X_12            0                    0.0
# 14              X_13            0                    0.0
# ...

# %%
def plot_correlation_map( df ):
    corr = train_data.corr()
    _ , ax = plt.subplots( figsize =( 20 , 15 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )

plot_correlation_map(train_data)

# %%
sns.boxplot(data=train_data,x=train_data['X_1'])

# %%
sns.boxplot(data=train_data,x=train_data['X_2'])

# %%
sns.boxplot(data=train_data,x=train_data['X_3'])

# %%
sns.boxplot(data=train_data,x=train_data['X_4'])
